# %% [markdown]
# # 05 — Decision Summary
#
# This notebook is an analytical working paper. It reads the local USAID SCMS extract and writes only anonymized derived outputs.

# %%
from pathlib import Path
import sys, os
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
sys.path.insert(0, str(ROOT / 'work' / 'python_packages'))
os.environ['MPLBACKEND']='Agg'
from procurement_intelligence.data import load_scms
import pandas as pd
pd.set_option('display.max_columns', 50)

# %%
import json
summary=json.loads((ROOT/'results/analysis_summary.json').read_text())
summary
# Out:
# {'source_rows': 10324,
#  'eligible_external_supplier_rows': 4920,
#  'scored_suppliers': 10,
#  'observed_value_usd': 542212022.3399999,
#  'delivery_comparison_coverage': 0.9997967479674796,
#  'comparable_line_coverage': 0.225,
#  'source_period': {'start': '2006-05-02', 'end': '2015-12-31'},
#  'action_counts': {'PROTECT': 4,
#   'RENEGOTIATE': 3,
#   'DEVELOP': 2,
#   'DIVERSIFY': 1}}

# %%
scorecard=pd.read_csv(ROOT/'results/supplier_decision_table.csv')
scorecard.groupby('action').agg(eligible_suppliers=('supplier_alias','size'), exposure_usd=('line_value_usd','sum')).sort_values('exposure_usd',ascending=False)
# Out:
#              eligible_suppliers  exposure_usd
# action
# DEVELOP                       2  1.873620e+08
# DIVERSIFY                     1  9.138371e+07
# RENEGOTIATE                   3  8.786151e+07
# PROTECT                       4  6.769802e+07

# %% [markdown]
# **Management use.** Review the anonymized scorecard with supplier, procurement and logistics owners; validate supplier identities and context before any intervention. The README is the management-facing decision summary; it uses the same result files.
