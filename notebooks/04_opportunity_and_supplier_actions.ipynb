# %% [markdown]
# # 04 — Opportunity & Supplier Actions
#
# This notebook is an analytical working paper. It reads the local USAID SCMS extract and writes only anonymized derived outputs.

# %%
from pathlib import Path
import sys, os
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
sys.path.insert(0, str(ROOT / 'work' / 'python_packages'))
os.environ['MPLBACKEND']='Agg'
from procurement_intelligence.data import load_scms
import pandas as pd
pd.set_option('display.max_columns', 50)

# %%
actions=pd.read_csv(ROOT/'results/supplier_decision_table.csv')
actions.groupby('action').agg(suppliers=('supplier_alias','size'), observed_value_usd=('line_value_usd','sum')).sort_values('observed_value_usd',ascending=False)
# Out:
#              suppliers  observed_value_usd
# action
# DEVELOP              2        1.873620e+08
# DIVERSIFY            1        9.138371e+07
# RENEGOTIATE          3        8.786151e+07
# PROTECT              4        6.769802e+07

# %%
actions[['supplier_alias','action','observable_risk_score','late_rate','mean_positive_price_variance','max_product_dependency']].sort_values('observable_risk_score',ascending=False)
# Out:
#   supplier_alias       action  observable_risk_score  late_rate  \
# 7    Supplier 14  RENEGOTIATE                   76.0   0.048780
# 1    Supplier 02    DIVERSIFY                   75.5   0.140719
# 4    Supplier 05      DEVELOP                   74.5   0.131429
# 6    Supplier 09  RENEGOTIATE                   70.5   0.015385
# 5    Supplier 07      PROTECT                   64.5   0.043011
# 2    Supplier 03  RENEGOTIATE                   54.5   0.006309
# 0    Supplier 01      DEVELOP                   52.5   0.129973
# 3    Supplier 04      PROTECT                   45.0   0.007220
# 9    Supplier 24      PROTECT                   21.2   0.000000
# 8    Supplier 22      PROTECT                   15.8   0.000000
#
#    mean_positive_price_variance  max_product_dependency
# 7                      0.020988                1.000000
# 1                      0.007041                1.000000
# 4                      0.009939                1.000000
# ...

# %% [markdown]
# Actions are review hypotheses. `RENEGOTIATE` requires comparable price evidence; `DEVELOP` requires schedule evidence; `DIVERSIFY` requires high score and material exposure. No savings are asserted.
